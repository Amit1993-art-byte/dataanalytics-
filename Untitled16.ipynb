# %%
# ASSIGNMENT 7                                 FILES AND EXCEPTIONS HANDLING

# %%
# Q 1. Discuss the scenarios where multithreading is preferable to multiprocessing and scenarios where
#     multiprocessing is a better choice.

 # ANS :

# Multithreading vs Multiprocessing:

# Multithreading is preferable when:

#  Dealing with I/O-bound tasks: When your program spends a lot of time waiting for external resources
#   like network requests, file operations, or user input. Threads can overlap these wait times, improving
#   overall efficiency.
#  Lower overhead: Creating and managing threads is generally less resource-intensive than creating processes.
#  Shared memory: Threads share the same memory space, facilitating easier communication and data sharing.

# Multiprocessing is a better choice when:

#  CPU-bound tasks:  When your program is primarily focused on computationally intensive operations
#   that utilize the CPU core. Multiple processes can leverage multiple CPU cores for parallel execution.
#  Isolation: Processes have their own memory space, which can be beneficial for isolating tasks and preventing
#   interference between them.
#  Improved stability: If one process crashes, it won't affect other processes, enhancing the overall stability of
#   your application.

# %%
# Q 2. Describe what a process pool is and how it helps in managing multiple processes efficiently.

# ANS :

# A process pool is a way to manage a set of worker processes that can be used to execute tasks in parallel.
# It provides a convenient way to distribute work across multiple processes, improving the performance of CPU-bound tasks.

# Here's how it helps:

#  Efficient resource utilization:  A process pool allows you to create a fixed number of worker processes that
#   can be reused for multiple tasks. This avoids the overhead of creating and destroying processes repeatedly.
#  Simplified task submission: You can submit tasks to the pool using simple functions, and the pool will
#   automatically assign the tasks to available worker processes.
#  Result handling:  Process pools provide mechanisms for retrieving results from the worker processes, making it
#   easier to manage the output of parallel computations.

# In summary, process pools offer a streamlined approach to parallel processing, improving efficiency and
# simplifying the management of multiple processes.

# %%
# Q 3. Explain what multiprocessing is and why it is used in Python programs.

# ANS:

# Multiprocessing in Python:

# Multiprocessing is a technique that allows you to create multiple processes to execute tasks concurrently.
# Each process runs in its own memory space, independent of other processes.

# Why use multiprocessing?

#  Improved performance: By utilizing multiple CPU cores, multiprocessing can significantly speed up the execution
#   of CPU-bound tasks.
#  Parallelism: It enables parallel execution of tasks, allowing your program to perform multiple operations
#   simultaneously.
#  Increased responsiveness: Multiprocessing can improve the responsiveness of your application by offloading
#   time-consuming tasks to separate processes.
#  Fault tolerance: If one process crashes, it won't affect other processes, enhancing the overall stability of
#   your application.

# %%
# Q 4. Write a Python program using multithreading where one thread adds numbers to a list, and another
#  thread removes numbers from the list. Implement a mechanism to avoid race conditions using
#  threading.Lock.

# import threading
# import time

# class SharedList:
#    def __init__(self):
#        self.data = []
#        self.lock = threading.Lock()

#    def add_number(self, number):
#        with self.lock:
#            self.data.append(number)
#            print(f"Added {number} to the list. Current list: {self.data}")

#    def remove_number(self):
#        with self.lock:
#            if self.data:
#                number = self.data.pop()
#                print(f"Removed {number} from the list. Current list: {self.data}")
#            else:
#                print("List is empty.")

#  def add_thread_function(shared_list):
#    for i in range(1, 6):
#        shared_list.add_number(i)
#        time.sleep(1)

# def remove_thread_function(shared_list):
 #   for _ in range(5):
 #       shared_list.remove_number()
 #       time.sleep(1)

# if __name__ == "__main__":
#    shared_list = SharedList()

 #   add_thread = threading.Thread(target=add_thread_function, args=(shared_list,))
 #   remove_thread = threading.Thread(target=remove_thread_function, args=(shared_list,))

 #   add_thread.start()
 #   remove_thread.start()

#    add_thread.join()
 #   remove_thread.join()

# %%
# Q 5. Describe the methods and tools available in Python for safely sharing data between threads and
#    processes.

# Methods and tools for safely sharing data between threads and processes in Python:

# For threads:

# 1.  Locks:
#     - `threading.Lock()`:  A basic lock that allows only one thread to access a shared resource at a time.
#       This prevents race conditions.
#     - `threading.RLock()`: A reentrant lock that can be acquired multiple times by the same thread.

# 2.  Condition Variables:
#     - `threading.Condition()`:  Provides a way for threads to wait for a specific condition to be met before
#       proceeding. This is useful for coordinating threads that need to synchronize their actions.

# 3.  Queues:
#     - `queue.Queue()`: A thread-safe queue that allows multiple threads to safely add and remove items.
#     - `queue.LifoQueue()`: A last-in, first-out (LIFO) queue.
#     - `queue.PriorityQueue()`: A priority queue that sorts items based on their priority.


# For processes:

# 1.  Pipes:
#     - `multiprocessing.Pipe()`: Creates a pair of connected pipes for inter-process communication. Data can be
#       sent and received through these pipes.

# 2.  Queues:
#     - `multiprocessing.Queue()`:  Similar to `queue.Queue()`, but designed for inter-process communication.

# 3.  Shared Memory:
#     - `multiprocessing.shared_memory`:  Allows processes to share memory directly, improving performance for
#       data exchange.

# 4.  Managers:
#     - `multiprocessing.Manager()`: Provides a way to create shared objects that can be accessed by multiple
#       processes. This includes dictionaries, lists, and other data structures.

# %%
# Q 6. Discuss why it’s crucial to handle exceptions in concurrent programs and the techniques available for
#     doing so.

#  Why handle exceptions in concurrent programs?

#  - Maintaining program stability: When an exception occurs in a thread or process, it can disrupt the entire
#    program if not handled properly. Exception handling ensures that the program doesn't crash and allows for
#    graceful recovery.
#  - Debugging and troubleshooting:  Handling exceptions provides valuable information about errors that occur
#    during concurrent execution. This helps in identifying the source of problems and debugging the code.
#  - Resource cleanup:  Exceptions can occur during resource allocation or usage. Proper exception handling
#    ensures that resources are released correctly, preventing leaks and improving overall system stability.
#  - Maintaining data integrity: In concurrent programs, multiple threads or processes might access shared data.
#    Exception handling helps maintain data integrity by ensuring that data is not corrupted due to unexpected
#    errors.


# Techniques for handling exceptions in concurrent programs:

# 1.  Try-Except Blocks:
#     -  Use `try-except` blocks to catch exceptions that might occur within threads or processes.
#     -  This allows you to handle errors gracefully and prevent the entire program from crashing.

# 2.   Thread or Task-level Exception Handling

# 3.   Centralized Error  Handling Mechanism

# %%
# Q 7. Create a program that uses a thread pool to calculate the factorial of numbers from 1 to 10 concurrently.
#    Use concurrent.futures.ThreadPoolExecutor to manage the threads.

# import concurrent.futures

# def factorial(n):
#  """Calculate the factorial of a number."""
#  result = 1
#  for i in range(1, n + 1):
#   result *= i
#  return result

# if __name__ == "__main__":
# with concurrent.futures.ThreadPoolExecutor() as executor:

#    results = list(executor.map(factorial, range(1, 11)))

 # for i, result in enumerate(results): # Fixed the indentation of this line to align with other statements in the block.
  # print(f"Factorial of {i + 1}: {result}")
# Out:
# Factorial of 1: 1
# Factorial of 2: 2
# Factorial of 3: 6
# Factorial of 4: 24
# Factorial of 5: 120
# Factorial of 6: 720
# Factorial of 7: 5040
# Factorial of 8: 40320
# Factorial of 9: 362880
# Factorial of 10: 3628800

# %%
# Q 8. Create a Python program that uses multiprocessing.Pool to compute the square of numbers from 1 to 10 in
#    parallel. Measure the time taken to perform this computation using a pool of different sizes (e.g., 2, 4, 8
#    processes).


# import multiprocessing
# import time

# def square(n):
#  """Calculate the square of a number."""
# return n * n

# if __name__ == "__main__":
#  numbers = list(range(1, 11))

# for num_processes in [2, 4, 8]: # Added this line back to iterate through different pool sizes
#    start_time = time.time()
#    with multiprocessing.Pool(processes=num_processes) as pool:
#      results = pool.map(square, numbers)
#    end_time = time.time()
#    print(f"Time taken with {num_processes} processes: {end_time - start_time} seconds")
#    print(f"Results: {results}")
# Out:
# Time taken with 2 processes: 0.02978515625 seconds
# Results: [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
# Time taken with 4 processes: 0.047522783279418945 seconds
# Results: [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
# Time taken with 8 processes: 0.08174991607666016 seconds
# Results: [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
